# %%
xprop #display program info with mouse press
# Out:
# WM_STATE(WM_STATE):
# 		window state: Normal
# 		icon window: 0x0
# _NET_WM_USER_TIME(CARDINAL) = 3294931
# WM_NORMAL_HINTS(WM_SIZE_HINTS):
# 		program specified location: 12, 26
# 		program specified minimum size: 588 by 66
# WM_NAME(UTF8_STRING) = "(Busy) commands - Google Chrome"
# _NET_WM_NAME(UTF8_STRING) = "(Busy) commands - Google Chrome"
# XdndAware(ATOM) = BITMAP
# _MOTIF_WM_HINTS(_MOTIF_WM_HINTS) = 0x2, 0x0, 0x1, 0x0, 0x0
# _NET_WM_ICON(CARDINAL) = 	Icon (64 x 64):
#
#
#
# 	                         ░░░░▒▒▒▒▒▒▒░░░
# 	                      ░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# 	                   ░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░░
# 	                 ░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# 	                ░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# 	              ░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# 	             ░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# 	            ░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# 	           ░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒░
# ...
